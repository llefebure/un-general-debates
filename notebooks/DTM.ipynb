# %% [markdown]
# # Dynamic Topic Model Exploration
#
# This notebook loads trained DTMs saved by `src/models/train_dtm.py` for exploration and analysis.

# %%
from src.models.dtm import Dtm
# %matplotlib inline

# %%
model = Dtm.load('2019-01-06T05:46:10')
model.summary([1975, 1995, 2015])
# Out:
# Topic 0
#          1975          1995       2015
# 0       south        africa    african
# 1      africa         south     africa
# 2     african       african      south
# 3        asia       country      union
# 4     country     continent    country
# 5       north        region   european
# 6   continent          asia  community
# 7        east     community    central
# 8         oau         north    support
# 9  government  organization     region
#
# Topic 1
#           1975         1995           2015
# 0       middle        peace      terrorism
# 1         arab       middle          state
# 2       israel         east         israel
# 3         east         drug    palestinian
# 4       people       israel      terrorist
# 5        right  palestinian          peace
# 6    territory         arab  international
# 7        peace      israeli           arab
# 8  palestinian      process      palestine
# 9    palestine       people       security
#
# Topic 2
# ...

# %%
model.top_term_table(2, [1975, 1995, 2015])
# Out:
#           1975           1995           2015
# 0      nuclear        nuclear        nuclear
# 1  disarmament         weapon         weapon
# 2       weapon         treaty           iran
# 3          arm    disarmament         treaty
# 4       soviet  proliferation            arm
# 5       treaty     convention       chemical
# 6       states            arm            non
# 7        union            non  international
# 8         race           test            use
# 9     military            ban  proliferation

# %%
model.label_topic(2, 1975)
# Out:
# [('Nuclear weapon', 185, 0.4103853166103363),
#  ('Disarmament', 175, 0.39178300052881243),
#  ('Soviet Union', 74, 0.36318098232150076),
#  ('Arms race', 83, 0.33175512254238126),
#  ('Treaty', 129, 0.3231854014098644),
#  ('Weapon', 158, 0.3216794364154339),
#  ('Country', 86, 0.2454272396862507),
#  ('Prohibition', 71, 0.22657060604542495),
#  ('Conference', 80, 0.21803260296583177),
#  ('World', 73, 0.17100771218538285)]

# %%
model.label_topic(2, 1995)
# Out:
# [('Nuclear proliferation', 100, 0.42861305475234984),
#  ('Nuclear weapons testing', 94, 0.4072051152586937),
#  ('Disarmament', 121, 0.4058385297656059),
#  ('Nuclear weapon', 201, 0.39600266218185426),
#  ('List of states with nuclear weapons', 88, 0.39542299807071685),
#  ('Treaty', 336, 0.3669604443013668),
#  ('Weapon', 161, 0.32751732170581815),
#  ('Negotiation', 74, 0.27482201904058456),
#  ('Conference', 114, 0.24491800367832184),
#  ('Party', 59, 0.17454852983355523)]

# %%
model.label_topic(2, 2015)
# Out:
# [('Nuclear proliferation', 26, 0.40089803040027616),
#  ('Arms Trade Treaty', 21, 0.39266141057014464),
#  ('Nuclear weapon', 67, 0.36092604845762255),
#  ('Weapon', 39, 0.3340762257575989),
#  ('Iran', 36, 0.3079981401562691),
#  ('Small arms', 28, 0.30135312527418134),
#  ('Treaty', 41, 0.2985733114182949),
#  ('Conference', 22, 0.21949825659394265),
#  ('Country', 25, 0.2111341029405594),
#  ('World', 38, 0.17045965418219566)]
